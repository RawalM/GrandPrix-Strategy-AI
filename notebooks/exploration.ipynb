# %%
import fastf1
import fastf1.plotting
import matplotlib.pyplot as plt
import pandas as pd

# 1. Enable the cache (Crucial for speed!)
# Make sure the folder 'data/cache' exists in your project root
fastf1.Cache.enable_cache('../data/cache') 

# 2. Setup plotting (Makes the graphs look like F1 style)
fastf1.plotting.setup_mpl(misc_mpl_mods=False)

print("Setup complete!")
# Out:
# Setup complete!
# /opt/miniconda3/lib/python3.13/site-packages/fastf1/plotting/_plotting.py:57: FutureWarning: The `misc_mpl_mods` argument was dropped from `.setup_mpl()` in version 3.6.0 and has no effect anymore. It will be removed in a future version of FastF1.
#   warnings.warn(

# %%
# Load the session
race = fastf1.get_session(2024, 'Bahrain', 'R')
race.load()

print("Race data loaded successfully!")
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.6.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '63', '4', '44', '81', '14', '18', '24', '20', '3', '22', '23', '27', '31', '10', '77', '2']
# Race data loaded successfully!

# %%
# Get all laps for Verstappen
race = fastf1.get_session(2024, 'Bahrain', 'R') 
race.load()
print(race.laps.pick_drivers('HAM'))


# Show the first 5 laps with specific columns
# cols = ['LapNumber', 'LapTime', 'Compound', 'TyreLife']
# print(race.laps.pick_driver('VER').head(10))
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.6.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '63', '4', '44', '81', '14', '18', '24', '20', '3', '22', '23', '27', '31', '10', '77', '2']
# ...

# %%
ver_laps = display.laps.pick_driver('VER')
#ver_laps = ver_laps.pick_quicklaps()

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(ver_laps['LapNumber'], ver_laps['LapTime'].dt.total_seconds(), label='VER Race Pace')

ax.set_xlabel('Lap Number')
ax.set_ylabel('Lap Time (Seconds)')
ax.set_title('Verstappen Pace - Bahrain 2024')
ax.legend()
plt.show()
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/fastf1/core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
